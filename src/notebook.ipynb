# %%
import yfinance as yf

tickers = yf.Tickers('msft aapl goog')

# access each ticker using (example)
tickers.tickers['MSFT'].info
tickers.tickers['AAPL'].history(period="1mo")
tickers.tickers['GOOG'].actions

# websocket
tickers.live()
# Out:
# Connected to WebSocket.
# Subscribed to symbols: ['MSFT', 'AAPL', 'GOOG']
# Listening for messages...
# {'id': 'MSFT', 'price': 478.69, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.023491, 'day_volume': '3438240', 'change': -4.950012, 'last_size': '117', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.75, 'time': '1767885685000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0172116, 'day_volume': '6971332', 'change': 3.2799988, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.25, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5748055, 'day_volume': '13469943', 'change': -4.100006, 'last_size': '100', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.29, 'time': '1767885685000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5594382, 'day_volume': '13472244', 'change': -4.0599976, 'last_size': '150', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.2804, 'time': '1767885686000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5631306, 'day_volume': '13473495', 'change': -4.0696106, 'last_size': '100', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.69, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.023491, 'day_volume': '3438254', 'change': -4.950012, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.75, 'time': '1767885685000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0171485, 'day_volume': '6971467', 'change': 3.2799988, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.25, 'time': '1767885686000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5748055, 'day_volume': '13475290', 'change': -4.100006, 'last_size': '100', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.69, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.023491, 'day_volume': '3438304', 'change': -4.950012, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.27, 'time': '1767885687000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5671277, 'day_volume': '13475816', 'change': -4.080017, 'last_size': '100', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.725, 'time': '1767885687000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0095073, 'day_volume': '6972035', 'change': 3.255005, 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.69, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.023491, 'day_volume': '3438890', 'change': -4.950012, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.23, 'time': '1767885688000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5822402, 'day_volume': '13476164', 'change': -4.119995, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.8, 'time': '1767885688000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.03265, 'day_volume': '6991501', 'change': 3.3299866, 'last_size': '100', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.75, 'time': '1767885688000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0171485, 'day_volume': '6992512', 'change': 3.2799988, 'last_size': '210', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.75, 'time': '1767885688000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0171485, 'day_volume': '6992583', 'change': 3.2799988, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.2365, 'time': '1767885689000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5800259, 'day_volume': '13476478', 'change': -4.113495, 'last_size': '200', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.69, 'time': '1767885684000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.023491, 'day_volume': '3438896', 'change': -4.950012, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.805, 'time': '1767885690000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0342021, 'day_volume': '6993393', 'change': 3.3349915, 'last_size': '400', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885689000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3439061', 'change': -5.01001, 'last_size': '40', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.2, 'time': '1767885690000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5940057, 'day_volume': '13481903', 'change': -4.149994, 'last_size': '435', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.2, 'time': '1767885690000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5940057, 'day_volume': '13481695', 'change': -4.149994, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.805, 'time': '1767885690000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0342021, 'day_volume': '6993504', 'change': 3.3349915, 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885689000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3439114', 'change': -5.01001, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.23, 'time': '1767885691000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5824832, 'day_volume': '13483816', 'change': -4.119995, 'last_size': '100', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.23, 'time': '1767885691000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5824832, 'day_volume': '13483829', 'change': -4.119995, 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885689000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3439124', 'change': -5.01001, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.23, 'time': '1767885691000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5824832, 'day_volume': '13484171', 'change': -4.119995, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.78, 'time': '1767885691000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0264513, 'day_volume': '6993606', 'change': 3.3099976, 'last_size': '100', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3440559', 'change': -5.01001, 'last_size': '45', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.74, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0140444, 'day_volume': '6995071', 'change': 3.269989, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.235, 'time': '1767885692000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5805726, 'day_volume': '13485798', 'change': -4.1150208, 'last_size': '200', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.75, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0171485, 'day_volume': '6994102', 'change': 3.2799988, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.235, 'time': '1767885692000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5805726, 'day_volume': '13485895', 'change': -4.1150208, 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3440730', 'change': -5.01001, 'last_size': '40', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.235, 'time': '1767885692000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5805726, 'day_volume': '13486062', 'change': -4.1150208, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.74, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0140444, 'day_volume': '6995180', 'change': 3.269989, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.24, 'time': '1767885695000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5786502, 'day_volume': '13487845', 'change': -4.110016, 'last_size': '100', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.74, 'time': '1767885693000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0140444, 'day_volume': '6995207', 'change': 3.269989, 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.66, 'time': '1767885695000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0296937, 'day_volume': '3440988', 'change': -4.980011, 'last_size': '65', 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.74, 'time': '1767885695000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 1.0140444, 'day_volume': '6996080', 'change': 3.269989, 'last_size': '232', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885696000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358322, 'day_volume': '3441109', 'change': -5.01001, 'last_size': '100', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.245, 'time': '1767885695000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5767279, 'day_volume': '13488489', 'change': -4.105011, 'price_hint': '2'}
# {'id': 'GOOG', 'price': 325.67, 'time': '1767885696000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': 0.99234414, 'day_volume': '6996799', 'change': 3.2000122, 'last_size': '100', 'price_hint': '2'}
# {'id': 'AAPL', 'price': 256.2499, 'time': '1767885697000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.5748407, 'day_volume': '13490004', 'change': -4.1000977, 'last_size': '600', 'price_hint': '2'}
# {'id': 'MSFT', 'price': 478.63, 'time': '1767885696000', 'exchange': 'NMS', 'quote_type': 8, 'market_hours': 1, 'change_percent': -1.0358964, 'day_volume': '3441507', 'change': -5.01001, 'last_size': '50', 'price_hint': '2'}
# Received keyboard interrupt.
# WebSocket connection closed.
